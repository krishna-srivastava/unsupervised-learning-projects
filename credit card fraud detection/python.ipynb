# %% [markdown]
# ## 🚨 Anomaly Detection (Fraud Detection)
#
# ### 🧠 Objective:
#
# Detect fraudulent transactions from a highly imbalanced dataset using Isolation Forest.
#
# ---
#
# ### ⚙️ Approach:
#
# * Scaled all features using StandardScaler
# * Applied Isolation Forest for anomaly detection
# * Set contamination based on expected fraud ratio
#
# ---
#
# ### 📊 Key Results:
#
# * Model detected anomalies close to actual fraud count
# * However, many fraud cases were missed initially (low recall)
#
# ---
#
# ### ⚖️ Precision vs Recall Trade-off:
#
# * Increasing contamination improved **recall** (more fraud detected)
# * But reduced **precision** (more false alarms)
#
# ---
#
# ### 💡 Insight:
#
# In fraud detection, **recall is more important than precision**, as missing a fraudulent transaction is more critical than raising a false alert.
#
# ---
#
# ### ✅ Conclusion:
#
# Isolation Forest is effective for detecting anomalies in imbalanced data, but careful tuning of contamination is required to balance precision and recall.
#
# ---

# %%
import pandas as pd

df = pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.274539e-12 -9.512736e-13 -4.398678e-13 -1.029671e-13
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -3.838944e-13  7.529013e-13 -3.405412e-14 -1.660106e-13  1.027627e-13
# ...

# %%
df.groupby("Class")["Class"].count()
# Out:
# Class
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="Class",data=df)
plt.title("Default Distribution")
plt.show()

# %%
X = df.drop("Class", axis=1)
y = df["Class"]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.ensemble import IsolationForest

model = IsolationForest(contamination=0.003, random_state=42)
df["anomaly"] = model.fit_predict(X_scaled)

# %%
df["anomaly"] = df["anomaly"].map({1: 0, -1: 1})
print(df["anomaly"].value_counts())
# Out:
# anomaly
# 0    283952
# 1       855
# Name: count, dtype: int64

# %%
df[df["anomaly"] == 1].head()
# Out:
#         Time         V1         V2         V3        V4         V5         V6  \
# 164    103.0  -6.093248 -12.114213  -5.694973  3.294389  -1.413792   4.776000
# 1388  1077.0  -3.936794  -3.670519  -1.453820  2.299750  -9.749440   6.456410
# 1632  1264.0 -11.140706  -9.612726 -12.389545  6.013346 -32.092129  21.393069
# 2178  1698.0  -5.849226 -11.754975  -3.333303  3.673246  -4.459583   0.659098
# 2622  2151.0  -2.574940  -2.669331  -3.080133  2.043551 -11.416881   7.885721
#
#              V7        V8        V9  ...       V22       V23       V24  \
# 164    4.808426 -0.228197 -0.525896  ... -2.264037 -3.553381  1.215279
# 1388  10.784088 -2.160016 -0.238116  ...  0.957186  2.441960  0.250607
# 1632  34.303177 -7.520784 -1.925732  ...  1.366110 -2.925888  0.843551
# 2178   4.527224 -0.985512  0.237794  ... -1.992179 -3.240351  0.609619
# 2622  12.219249 -1.828209 -1.475925  ...  0.264090  2.219739 -0.771131
#
#            V25       V26       V27       V28   Amount  Class  anomaly
# ...

# %%
from sklearn.metrics import classification_report

print(classification_report(df["Class"], df["anomaly"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    284315
#            1       0.21      0.36      0.26       492
#
#     accuracy                           1.00    284807
#    macro avg       0.60      0.68      0.63    284807
# weighted avg       1.00      1.00      1.00    284807

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(df["Class"],df["anomaly"])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=["Normal", "Fraud"])

disp.plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.show()
